# %%
# !nvidia-smi
# Out:
# Sun Jul 21 10:47:52 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.26                 Driver Version: 546.26       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1650 Ti   WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   71C    P8               3W /  50W |    967MiB /  4096MiB |     12%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1040    C+G   ...0_x64__8wekyb3d8bbwe\DevHome.PI.exe    N/A      |
# |    0   N/A  N/A      1804    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      6916    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10832    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     11308    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     13364    C+G   ...90.0_x64__zpdnekdrzrea0\Spotify.exe    N/A      |
# |    0   N/A  N/A     14688    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     16504    C+G   ...ta\Local\Programs\Notion\Notion.exe    N/A      |
# |    0   N/A  N/A     16752    C+G   ..._8wekyb3d8bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     24688    C+G   ...2.2.0_x64__gqbn7fs4pywxm\Db.App.exe    N/A      |
# |    0   N/A  N/A     29940    C+G   ...Programs\Microsoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     30596    C+G   ...64__v10z8vjag6ke6\HP.JumpStarts.exe    N/A      |
# |    0   N/A  N/A     32536    C+G   ...42.0_x64__8wekyb3d8bbwe\GameBar.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %%
import os

# Path to the directory you want to list
dataset_path = './srgan_dataset'

# List all files and folders in the directory
files = os.listdir(dataset_path)

# Print the list of files
for file in files:
    print(file)
# Out:
# change_names.ipynb
# test
# test_HR
# test_LR
# test_SR
# test_SR_content
# train_HR
# train_LR
# train_SR
# train_SR_content
# valid_HR
# valid_LR
# valid_SR
# valid_SR_content

# %%
# Do set your runtime to GPU. You will need it
import torch
import math
from os import listdir
import numpy as np
from torch.autograd import Variable
from torchvision.io import read_image
from torchvision.transforms import Compose, RandomCrop, ToTensor, ToPILImage, CenterCrop, Resize,Normalize
import torchvision.transforms.functional as TF
from torch.utils.data import DataLoader, Dataset
from PIL import Image
from os.path import join

import matplotlib
matplotlib.use('Qt5Agg')

import matplotlib.pyplot as plt

# %%
torch.autograd.set_detect_anomaly(True)

# %%
UPSCALE_FACTOR = 1
CROP_SIZE = 160

# %%
#mean = np.array([0.485, 0.456, 0.406])
#std = np.array([0.229, 0.224, 0.225])
mean = np.array([0.5,0.5,0.5])
std = np.array([0.5,0.5,0.5])

# %%
# Now, I will load in some code for the dataset and dataloaders.
# Link to this notebook will be in the description, so you can get it from there
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in ['.png', '.jpg', '.jpeg', '.PNG', '.JPG', '.JPEG'])


def calculate_valid_crop_size(crop_size, upscale_factor):
    return crop_size - (crop_size % upscale_factor)


def train_hr_transform(crop_size):
    return Compose([
        RandomCrop(crop_size),
        ToTensor(),
    ])


def train_lr_transform(crop_size, upscale_factor):
    return Compose([
        RandomCrop(crop_size),
        ToTensor(),
    ])


def display_transform():
    return Compose([
        ToPILImage(),
        Resize(400),
        CenterCrop(400),
        ToTensor()
    ])


class TrainDatasetFromFolder(Dataset):
    def __init__(self, dataset_dir, crop_size, upscale_factor):
        super(TrainDatasetFromFolder, self).__init__()
        self.image_filenames = [join(dataset_dir, x) for x in listdir(dataset_dir) if is_image_file(x)]
        crop_size = calculate_valid_crop_size(crop_size, upscale_factor)
        self.hr_transform = train_hr_transform(crop_size)
        self.lr_transform = train_lr_transform(crop_size, upscale_factor)

    def __getitem__(self, index):
        hr_image = self.hr_transform(Image.open(self.image_filenames[index]))
        lr_image = self.lr_transform(hr_image)
        return lr_image, hr_image

    def __len__(self):
        return len(self.image_filenames)

# %%
class createDataset(Dataset):
    def __init__(self,dataset_path,data_type,crop_size=CROP_SIZE):
        super(Dataset, self).__init__()
        self.image_filenames = listdir(f"{dataset_path}/{data_type}_HR")
        self.path_HR = f"{dataset_path}/{data_type}_HR"
        self.path_LR = f"{dataset_path}/{data_type}_LR"
        self.crop_size = crop_size

    def __getitem__(self, index):
        image_filename = self.image_filenames[index]
        image_HR = read_image(join(self.path_HR,image_filename))
        image_HR = image_HR.type(torch.float)
        image_LR = read_image(join(self.path_LR,image_filename))
        image_LR = image_LR.type(torch.float)

        #TF.normalize(image_HR, mean=mean, std=std, inplace=True)
        #TF.normalize(image_LR, mean=mean, std=std, inplace=True)

        #image_HR = Normalize(mean=mean, std=std)(image_HR)
        #image_LR = Normalize(mean=mean, std=std)(image_LR)

        image_HR /= 255
        image_LR /= 255

        i, j, h, w = RandomCrop.get_params(image_HR, output_size=(self.crop_size, self.crop_size))
        image_HR = TF.crop(image_HR, i, j, h, w)
        image_LR = TF.crop(image_LR, i, j, h, w)

        return image_LR,image_HR

    def __len__(self):
        return len(self.image_filenames)

# %%
train_set = createDataset(dataset_path,"train")
trainloader = DataLoader(train_set,batch_size=16,shuffle=True)

# %%
# %matplotlib inline

lrimages,hrimages = next(iter(trainloader))
print(lrimages.size(),hrimages.size())
n = np.random.randint(0,16)

fig,axes = plt.subplots(1,2,figsize=(7,14))
axes[0].imshow(lrimages[n].squeeze().permute(1,2,0))
axes[1].imshow(hrimages[n].squeeze().permute(1,2,0))
axes[0].axis("off")
axes[0].set_title("LR")
axes[1].axis("off")
axes[1].set_title("HR")
plt.show()
# Out:
# torch.Size([16, 3, 160, 160]) torch.Size([16, 3, 160, 160])

# %%
(lrimages).max(),(lrimages).min(),(lrimages).mean()
# Out:
# (tensor(1.), tensor(0.), tensor(0.4576))

# %%
from torch import nn, optim

# %%
# Now we will start implementing the model. We will start in this vid, and co,plee
# in the next video
class ResidualBlock(nn.Module):
  def __init__(self, channels):
    super(ResidualBlock, self).__init__()
    self.conv1 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
    self.bn1 = nn.BatchNorm2d(channels)
    self.prelu = nn.PReLU()
    self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
    self.bn2 = nn.BatchNorm2d(channels)
  def forward(self, x):
    residual = self.conv1(x)
    residual = self.bn1(residual)
    residual = self.prelu(residual)
    residual = self.conv2(residual)
    residual = self.bn2(residual)
    return x + residual

# We just implemented a pretty standard residual block here

# %%
class UpsampleBlock(nn.Module):
  def __init__(self, in_channels, up_scale):
    super(UpsampleBlock, self).__init__()
    self.conv = nn.Conv2d(in_channels, in_channels * up_scale ** 2,
                          kernel_size=3, padding=1)
    self.pixel_shuffle = nn.PixelShuffle(up_scale)
    self.prelu = nn.PReLU()
  def forward(self, x):
    x = self.conv(x)
    x = self.pixel_shuffle(x)
    x = self.prelu(x)
    return x

# %%
class Generator(nn.Module):
  def __init__(self, scale_factor):
    super(Generator, self).__init__()
    upsample_block_num = int(math.log(scale_factor, 2))

    self.block1 = nn.Sequential(
        nn.Conv2d(3, 64, kernel_size=9, padding=4),
        nn.PReLU()
    )

    self.block2 = ResidualBlock(64)
    self.block3 = ResidualBlock(64)
    self.block4 = ResidualBlock(64)
    self.block5 = ResidualBlock(64)
    self.block6 = ResidualBlock(64)
    self.block7 = nn.Sequential(
        nn.Conv2d(64, 64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64)
    )
    block8 = [UpsampleBlock(64, 2) for _ in range(upsample_block_num)]
    block8.append(nn.Conv2d(64, 3, kernel_size=9, padding=4))
    self.block8 = nn.Sequential(*block8)
  def forward(self, x):
    block1 = self.block1(x)
    block2 = self.block2(block1)
    block3 = self.block3(block2)
    block4 = self.block4(block3)
    block5 = self.block5(block4)
    block6 = self.block6(block5)
    block7 = self.block7(block6)
    block8 = self.block8(block1 + block7)
    return block8

# %%
class Discriminator(nn.Module):
  def __init__(self):
    super(Discriminator, self).__init__()
    self.net = nn.Sequential(
        nn.Conv2d(3, 64, kernel_size=3, padding=1),
        nn.LeakyReLU(0.2),

        nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(64),
        nn.LeakyReLU(0.2),

        nn.Conv2d(64, 128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.LeakyReLU(0.2),

        nn.Conv2d(128, 256, kernel_size=3, padding=1),
        nn.BatchNorm2d(256),
        nn.LeakyReLU(0.2),

        nn.Conv2d(256, 256, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(256),
        nn.LeakyReLU(0.2),

        nn.Conv2d(256, 512, kernel_size=3, padding=1),
        nn.BatchNorm2d(512),
        nn.LeakyReLU(0.2),

        nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(512),
        nn.LeakyReLU(0.2),

        nn.AdaptiveAvgPool2d(1),
        nn.Conv2d(512, 1024, kernel_size=1),
        nn.LeakyReLU(0.2),
        nn.Conv2d(1024, 1, kernel_size=1)
    )
  def forward(self, x):
    batch_size=x.size()[0]
    return torch.sigmoid(self.net(x).view(batch_size))

# %%
# Path to the directory you want to list
models_path = './models'
CWNU_path = './'

# %%
import sys
#sys.path.append(models_path)
sys.path.append(CWNU_path)

from models.yolo import Model

# %%
custom_yolo_model = Model(cfg=models_path+"/custom_yolov5s.yaml")
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     32364  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 283 layers, 7271276 parameters, 7271276 gradients, 17.0 GFLOPs

# %%
pre_trained_yolo_weights_path = './runs/train/yolov5s_results/weights'

# List all files and folders in the directory
files = os.listdir(pre_trained_yolo_weights_path)

if "best.pt" in files:
  print("Found")
else:
  print("Not Found")
# Out:
# Found

# %%
saved_dict = torch.load(pre_trained_yolo_weights_path+"/best.pt")
saved_dict
# Out:
# {'epoch': -1,
#  'best_fitness': None,
#  'model': Model(
#    (model): Sequential(
#      (0): Focus(
#        (conv): Conv(
#          (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#          (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#      )
#      (1): Conv(
#        (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (2): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (3): Conv(
#        (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (4): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#          (1): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#          (2): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (5): Conv(
#        (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (6): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#          (1): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#          (2): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (7): Conv(
#        (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (8): SPP(
#        (cv1): Conv(
#          (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv(
#          (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (m): ModuleList(
#          (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#          (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#          (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#        )
#      )
#      (9): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (10): Conv(
#        (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (11): Upsample(scale_factor=2.0, mode='nearest')
#      (12): Concat()
#      (13): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (14): Conv(
#        (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (15): Upsample(scale_factor=2.0, mode='nearest')
#      (16): Concat()
#      (17): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (18): Conv(
#        (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (19): Concat()
#      (20): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (21): Conv(
#        (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (22): Concat()
#      (23): BottleneckCSP(
#        (cv1): Conv(
#          (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (cv4): Conv(
#          (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#        (m): Sequential(
#          (0): Bottleneck(
#            (cv1): Conv(
#              (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#            (cv2): Conv(
#              (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#              (act): SiLU(inplace=True)
#            )
#          )
#        )
#      )
#      (24): Detect(
#        (m): ModuleList(
#          (0): Conv2d(128, 36, kernel_size=(1, 1), stride=(1, 1))
#          (1): Conv2d(256, 36, kernel_size=(1, 1), stride=(1, 1))
#          (2): Conv2d(512, 36, kernel_size=(1, 1), stride=(1, 1))
#        )
#      )
#    )
#  ),
#  'ema': None,
#  'updates': None,
#  'optimizer': None,
#  'wandb_id': None,
#  'date': '2024-06-21T07:13:58.033838'}

# %%
# Now we got to make the Generator Loss
class TVLoss(nn.Module):
  def __init__(self, tv_loss_weight=1):
    super(TVLoss, self).__init__()
    self.tv_loss_weight=tv_loss_weight
  def forward(self, x):
    batch_size=x.size()[0]
    h_x = x.size()[2]
    w_x = x.size()[3]

    count_h = self.tensor_size(x[:, :, 1:, :])
    count_w = self.tensor_size(x[:, :, :, 1:])

    h_tv = torch.pow(x[:, :, 1:, :] - x[:, :, :h_x - 1, :], 2).sum()
    w_tv = torch.pow(x[:, :, :, 1:] - x[:, :, :, :w_x - 1], 2).sum()
    return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

  # Forgot to implement an important method
  @staticmethod # Must add this
  def tensor_size(t):
    return t.size()[1] * t.size()[2] * t.size()[3]

# %%
custom_yolo_model.load_state_dict(saved_dict["model"].state_dict())
# Out:
# <All keys matched successfully>

# %%
from models.yolo import Model

class YOLOv5FeatureExtractor(Model):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        # self.load_state_dict()

    def load_another(self,inspo):
        self.model.load_state_dict(inspo)

    def forward(self, x):
        # Pass through layers upto the point you need (as an example, layer 3)
        x = self.model[0:9](x)
        return x

# Load your model
feature_extractor = YOLOv5FeatureExtractor(models_path+'/custom_yolov5s.yaml')
len(feature_extractor.model)

# img = torch.randn(5, 3, 640, 640)  # Example input
# features = feature_extractor(img)
# print(features.shape)
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     32364  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# AutoAnchor: Reversing anchor order
# custom_YOLOv5s summary: 283 layers, 7271276 parameters, 7271276 gradients, 10.2 GFLOPs
# 25

# %%
custom_yolo_dict_keys = list(custom_yolo_model.state_dict().keys())
feature_extractor_dict_keys = list(feature_extractor.state_dict().keys())

for i in range(len(feature_extractor_dict_keys)):
  print(custom_yolo_dict_keys[i],"   -   ",feature_extractor_dict_keys[i])
# Out:
# model.0.conv.conv.weight    -    model.0.conv.conv.weight
# model.0.conv.bn.weight    -    model.0.conv.bn.weight
# model.0.conv.bn.bias    -    model.0.conv.bn.bias
# model.0.conv.bn.running_mean    -    model.0.conv.bn.running_mean
# model.0.conv.bn.running_var    -    model.0.conv.bn.running_var
# model.0.conv.bn.num_batches_tracked    -    model.0.conv.bn.num_batches_tracked
# model.1.conv.weight    -    model.1.conv.weight
# model.1.bn.weight    -    model.1.bn.weight
# model.1.bn.bias    -    model.1.bn.bias
# model.1.bn.running_mean    -    model.1.bn.running_mean
# model.1.bn.running_var    -    model.1.bn.running_var
# model.1.bn.num_batches_tracked    -    model.1.bn.num_batches_tracked
# model.2.cv1.conv.weight    -    model.2.cv1.conv.weight
# model.2.cv1.bn.weight    -    model.2.cv1.bn.weight
# model.2.cv1.bn.bias    -    model.2.cv1.bn.bias
# model.2.cv1.bn.running_mean    -    model.2.cv1.bn.running_mean
# model.2.cv1.bn.running_var    -    model.2.cv1.bn.running_var
# model.2.cv1.bn.num_batches_tracked    -    model.2.cv1.bn.num_batches_tracked
# model.2.cv2.weight    -    model.2.cv2.weight
# model.2.cv3.weight    -    model.2.cv3.weight
# model.2.cv4.conv.weight    -    model.2.cv4.conv.weight
# model.2.cv4.bn.weight    -    model.2.cv4.bn.weight
# model.2.cv4.bn.bias    -    model.2.cv4.bn.bias
# model.2.cv4.bn.running_mean    -    model.2.cv4.bn.running_mean
# model.2.cv4.bn.running_var    -    model.2.cv4.bn.running_var
# model.2.cv4.bn.num_batches_tracked    -    model.2.cv4.bn.num_batches_tracked
# model.2.bn.weight    -    model.2.bn.weight
# model.2.bn.bias    -    model.2.bn.bias
# model.2.bn.running_mean    -    model.2.bn.running_mean
# model.2.bn.running_var    -    model.2.bn.running_var
# model.2.bn.num_batches_tracked    -    model.2.bn.num_batches_tracked
# model.2.m.0.cv1.conv.weight    -    model.2.m.0.cv1.conv.weight
# model.2.m.0.cv1.bn.weight    -    model.2.m.0.cv1.bn.weight
# model.2.m.0.cv1.bn.bias    -    model.2.m.0.cv1.bn.bias
# model.2.m.0.cv1.bn.running_mean    -    model.2.m.0.cv1.bn.running_mean
# model.2.m.0.cv1.bn.running_var    -    model.2.m.0.cv1.bn.running_var
# model.2.m.0.cv1.bn.num_batches_tracked    -    model.2.m.0.cv1.bn.num_batches_tracked
# model.2.m.0.cv2.conv.weight    -    model.2.m.0.cv2.conv.weight
# model.2.m.0.cv2.bn.weight    -    model.2.m.0.cv2.bn.weight
# model.2.m.0.cv2.bn.bias    -    model.2.m.0.cv2.bn.bias
# model.2.m.0.cv2.bn.running_mean    -    model.2.m.0.cv2.bn.running_mean
# model.2.m.0.cv2.bn.running_var    -    model.2.m.0.cv2.bn.running_var
# model.2.m.0.cv2.bn.num_batches_tracked    -    model.2.m.0.cv2.bn.num_batches_tracked
# model.3.conv.weight    -    model.3.conv.weight
# model.3.bn.weight    -    model.3.bn.weight
# model.3.bn.bias    -    model.3.bn.bias
# model.3.bn.running_mean    -    model.3.bn.running_mean
# model.3.bn.running_var    -    model.3.bn.running_var
# model.3.bn.num_batches_tracked    -    model.3.bn.num_batches_tracked
# model.4.cv1.conv.weight    -    model.4.cv1.conv.weight
# model.4.cv1.bn.weight    -    model.4.cv1.bn.weight
# model.4.cv1.bn.bias    -    model.4.cv1.bn.bias
# model.4.cv1.bn.running_mean    -    model.4.cv1.bn.running_mean
# model.4.cv1.bn.running_var    -    model.4.cv1.bn.running_var
# model.4.cv1.bn.num_batches_tracked    -    model.4.cv1.bn.num_batches_tracked
# model.4.cv2.weight    -    model.4.cv2.weight
# model.4.cv3.weight    -    model.4.cv3.weight
# model.4.cv4.conv.weight    -    model.4.cv4.conv.weight
# model.4.cv4.bn.weight    -    model.4.cv4.bn.weight
# model.4.cv4.bn.bias    -    model.4.cv4.bn.bias
# model.4.cv4.bn.running_mean    -    model.4.cv4.bn.running_mean
# model.4.cv4.bn.running_var    -    model.4.cv4.bn.running_var
# model.4.cv4.bn.num_batches_tracked    -    model.4.cv4.bn.num_batches_tracked
# model.4.bn.weight    -    model.4.bn.weight
# model.4.bn.bias    -    model.4.bn.bias
# model.4.bn.running_mean    -    model.4.bn.running_mean
# model.4.bn.running_var    -    model.4.bn.running_var
# model.4.bn.num_batches_tracked    -    model.4.bn.num_batches_tracked
# model.4.m.0.cv1.conv.weight    -    model.4.m.0.cv1.conv.weight
# model.4.m.0.cv1.bn.weight    -    model.4.m.0.cv1.bn.weight
# model.4.m.0.cv1.bn.bias    -    model.4.m.0.cv1.bn.bias
# model.4.m.0.cv1.bn.running_mean    -    model.4.m.0.cv1.bn.running_mean
# model.4.m.0.cv1.bn.running_var    -    model.4.m.0.cv1.bn.running_var
# model.4.m.0.cv1.bn.num_batches_tracked    -    model.4.m.0.cv1.bn.num_batches_tracked
# model.4.m.0.cv2.conv.weight    -    model.4.m.0.cv2.conv.weight
# model.4.m.0.cv2.bn.weight    -    model.4.m.0.cv2.bn.weight
# model.4.m.0.cv2.bn.bias    -    model.4.m.0.cv2.bn.bias
# model.4.m.0.cv2.bn.running_mean    -    model.4.m.0.cv2.bn.running_mean
# model.4.m.0.cv2.bn.running_var    -    model.4.m.0.cv2.bn.running_var
# model.4.m.0.cv2.bn.num_batches_tracked    -    model.4.m.0.cv2.bn.num_batches_tracked
# model.4.m.1.cv1.conv.weight    -    model.4.m.1.cv1.conv.weight
# model.4.m.1.cv1.bn.weight    -    model.4.m.1.cv1.bn.weight
# model.4.m.1.cv1.bn.bias    -    model.4.m.1.cv1.bn.bias
# model.4.m.1.cv1.bn.running_mean    -    model.4.m.1.cv1.bn.running_mean
# model.4.m.1.cv1.bn.running_var    -    model.4.m.1.cv1.bn.running_var
# model.4.m.1.cv1.bn.num_batches_tracked    -    model.4.m.1.cv1.bn.num_batches_tracked
# model.4.m.1.cv2.conv.weight    -    model.4.m.1.cv2.conv.weight
# model.4.m.1.cv2.bn.weight    -    model.4.m.1.cv2.bn.weight
# model.4.m.1.cv2.bn.bias    -    model.4.m.1.cv2.bn.bias
# model.4.m.1.cv2.bn.running_mean    -    model.4.m.1.cv2.bn.running_mean
# model.4.m.1.cv2.bn.running_var    -    model.4.m.1.cv2.bn.running_var
# model.4.m.1.cv2.bn.num_batches_tracked    -    model.4.m.1.cv2.bn.num_batches_tracked
# model.4.m.2.cv1.conv.weight    -    model.4.m.2.cv1.conv.weight
# model.4.m.2.cv1.bn.weight    -    model.4.m.2.cv1.bn.weight
# model.4.m.2.cv1.bn.bias    -    model.4.m.2.cv1.bn.bias
# model.4.m.2.cv1.bn.running_mean    -    model.4.m.2.cv1.bn.running_mean
# model.4.m.2.cv1.bn.running_var    -    model.4.m.2.cv1.bn.running_var
# model.4.m.2.cv1.bn.num_batches_tracked    -    model.4.m.2.cv1.bn.num_batches_tracked
# model.4.m.2.cv2.conv.weight    -    model.4.m.2.cv2.conv.weight
# model.4.m.2.cv2.bn.weight    -    model.4.m.2.cv2.bn.weight
# model.4.m.2.cv2.bn.bias    -    model.4.m.2.cv2.bn.bias
# model.4.m.2.cv2.bn.running_mean    -    model.4.m.2.cv2.bn.running_mean
# model.4.m.2.cv2.bn.running_var    -    model.4.m.2.cv2.bn.running_var
# model.4.m.2.cv2.bn.num_batches_tracked    -    model.4.m.2.cv2.bn.num_batches_tracked
# model.5.conv.weight    -    model.5.conv.weight
# model.5.bn.weight    -    model.5.bn.weight
# model.5.bn.bias    -    model.5.bn.bias
# model.5.bn.running_mean    -    model.5.bn.running_mean
# model.5.bn.running_var    -    model.5.bn.running_var
# model.5.bn.num_batches_tracked    -    model.5.bn.num_batches_tracked
# model.6.cv1.conv.weight    -    model.6.cv1.conv.weight
# model.6.cv1.bn.weight    -    model.6.cv1.bn.weight
# model.6.cv1.bn.bias    -    model.6.cv1.bn.bias
# model.6.cv1.bn.running_mean    -    model.6.cv1.bn.running_mean
# model.6.cv1.bn.running_var    -    model.6.cv1.bn.running_var
# model.6.cv1.bn.num_batches_tracked    -    model.6.cv1.bn.num_batches_tracked
# model.6.cv2.weight    -    model.6.cv2.weight
# model.6.cv3.weight    -    model.6.cv3.weight
# model.6.cv4.conv.weight    -    model.6.cv4.conv.weight
# model.6.cv4.bn.weight    -    model.6.cv4.bn.weight
# model.6.cv4.bn.bias    -    model.6.cv4.bn.bias
# model.6.cv4.bn.running_mean    -    model.6.cv4.bn.running_mean
# model.6.cv4.bn.running_var    -    model.6.cv4.bn.running_var
# model.6.cv4.bn.num_batches_tracked    -    model.6.cv4.bn.num_batches_tracked
# model.6.bn.weight    -    model.6.bn.weight
# model.6.bn.bias    -    model.6.bn.bias
# model.6.bn.running_mean    -    model.6.bn.running_mean
# model.6.bn.running_var    -    model.6.bn.running_var
# model.6.bn.num_batches_tracked    -    model.6.bn.num_batches_tracked
# model.6.m.0.cv1.conv.weight    -    model.6.m.0.cv1.conv.weight
# model.6.m.0.cv1.bn.weight    -    model.6.m.0.cv1.bn.weight
# model.6.m.0.cv1.bn.bias    -    model.6.m.0.cv1.bn.bias
# model.6.m.0.cv1.bn.running_mean    -    model.6.m.0.cv1.bn.running_mean
# model.6.m.0.cv1.bn.running_var    -    model.6.m.0.cv1.bn.running_var
# model.6.m.0.cv1.bn.num_batches_tracked    -    model.6.m.0.cv1.bn.num_batches_tracked
# model.6.m.0.cv2.conv.weight    -    model.6.m.0.cv2.conv.weight
# model.6.m.0.cv2.bn.weight    -    model.6.m.0.cv2.bn.weight
# model.6.m.0.cv2.bn.bias    -    model.6.m.0.cv2.bn.bias
# model.6.m.0.cv2.bn.running_mean    -    model.6.m.0.cv2.bn.running_mean
# model.6.m.0.cv2.bn.running_var    -    model.6.m.0.cv2.bn.running_var
# model.6.m.0.cv2.bn.num_batches_tracked    -    model.6.m.0.cv2.bn.num_batches_tracked
# model.6.m.1.cv1.conv.weight    -    model.6.m.1.cv1.conv.weight
# model.6.m.1.cv1.bn.weight    -    model.6.m.1.cv1.bn.weight
# model.6.m.1.cv1.bn.bias    -    model.6.m.1.cv1.bn.bias
# model.6.m.1.cv1.bn.running_mean    -    model.6.m.1.cv1.bn.running_mean
# model.6.m.1.cv1.bn.running_var    -    model.6.m.1.cv1.bn.running_var
# model.6.m.1.cv1.bn.num_batches_tracked    -    model.6.m.1.cv1.bn.num_batches_tracked
# model.6.m.1.cv2.conv.weight    -    model.6.m.1.cv2.conv.weight
# model.6.m.1.cv2.bn.weight    -    model.6.m.1.cv2.bn.weight
# model.6.m.1.cv2.bn.bias    -    model.6.m.1.cv2.bn.bias
# model.6.m.1.cv2.bn.running_mean    -    model.6.m.1.cv2.bn.running_mean
# model.6.m.1.cv2.bn.running_var    -    model.6.m.1.cv2.bn.running_var
# model.6.m.1.cv2.bn.num_batches_tracked    -    model.6.m.1.cv2.bn.num_batches_tracked
# model.6.m.2.cv1.conv.weight    -    model.6.m.2.cv1.conv.weight
# model.6.m.2.cv1.bn.weight    -    model.6.m.2.cv1.bn.weight
# model.6.m.2.cv1.bn.bias    -    model.6.m.2.cv1.bn.bias
# model.6.m.2.cv1.bn.running_mean    -    model.6.m.2.cv1.bn.running_mean
# model.6.m.2.cv1.bn.running_var    -    model.6.m.2.cv1.bn.running_var
# model.6.m.2.cv1.bn.num_batches_tracked    -    model.6.m.2.cv1.bn.num_batches_tracked
# model.6.m.2.cv2.conv.weight    -    model.6.m.2.cv2.conv.weight
# model.6.m.2.cv2.bn.weight    -    model.6.m.2.cv2.bn.weight
# model.6.m.2.cv2.bn.bias    -    model.6.m.2.cv2.bn.bias
# model.6.m.2.cv2.bn.running_mean    -    model.6.m.2.cv2.bn.running_mean
# model.6.m.2.cv2.bn.running_var    -    model.6.m.2.cv2.bn.running_var
# model.6.m.2.cv2.bn.num_batches_tracked    -    model.6.m.2.cv2.bn.num_batches_tracked
# model.7.conv.weight    -    model.7.conv.weight
# model.7.bn.weight    -    model.7.bn.weight
# model.7.bn.bias    -    model.7.bn.bias
# model.7.bn.running_mean    -    model.7.bn.running_mean
# model.7.bn.running_var    -    model.7.bn.running_var
# model.7.bn.num_batches_tracked    -    model.7.bn.num_batches_tracked
# model.8.cv1.conv.weight    -    model.8.cv1.conv.weight
# model.8.cv1.bn.weight    -    model.8.cv1.bn.weight
# model.8.cv1.bn.bias    -    model.8.cv1.bn.bias
# model.8.cv1.bn.running_mean    -    model.8.cv1.bn.running_mean
# model.8.cv1.bn.running_var    -    model.8.cv1.bn.running_var
# model.8.cv1.bn.num_batches_tracked    -    model.8.cv1.bn.num_batches_tracked
# model.8.cv2.conv.weight    -    model.8.cv2.conv.weight
# model.8.cv2.bn.weight    -    model.8.cv2.bn.weight
# model.8.cv2.bn.bias    -    model.8.cv2.bn.bias
# model.8.cv2.bn.running_mean    -    model.8.cv2.bn.running_mean
# model.8.cv2.bn.running_var    -    model.8.cv2.bn.running_var
# model.8.cv2.bn.num_batches_tracked    -    model.8.cv2.bn.num_batches_tracked
# model.9.cv1.conv.weight    -    model.9.cv1.conv.weight
# model.9.cv1.bn.weight    -    model.9.cv1.bn.weight
# model.9.cv1.bn.bias    -    model.9.cv1.bn.bias
# model.9.cv1.bn.running_mean    -    model.9.cv1.bn.running_mean
# model.9.cv1.bn.running_var    -    model.9.cv1.bn.running_var
# model.9.cv1.bn.num_batches_tracked    -    model.9.cv1.bn.num_batches_tracked
# model.9.cv2.weight    -    model.9.cv2.weight
# model.9.cv3.weight    -    model.9.cv3.weight
# model.9.cv4.conv.weight    -    model.9.cv4.conv.weight
# model.9.cv4.bn.weight    -    model.9.cv4.bn.weight
# model.9.cv4.bn.bias    -    model.9.cv4.bn.bias
# model.9.cv4.bn.running_mean    -    model.9.cv4.bn.running_mean
# model.9.cv4.bn.running_var    -    model.9.cv4.bn.running_var
# model.9.cv4.bn.num_batches_tracked    -    model.9.cv4.bn.num_batches_tracked
# model.9.bn.weight    -    model.9.bn.weight
# model.9.bn.bias    -    model.9.bn.bias
# model.9.bn.running_mean    -    model.9.bn.running_mean
# model.9.bn.running_var    -    model.9.bn.running_var
# model.9.bn.num_batches_tracked    -    model.9.bn.num_batches_tracked
# model.9.m.0.cv1.conv.weight    -    model.9.m.0.cv1.conv.weight
# model.9.m.0.cv1.bn.weight    -    model.9.m.0.cv1.bn.weight
# model.9.m.0.cv1.bn.bias    -    model.9.m.0.cv1.bn.bias
# model.9.m.0.cv1.bn.running_mean    -    model.9.m.0.cv1.bn.running_mean
# model.9.m.0.cv1.bn.running_var    -    model.9.m.0.cv1.bn.running_var
# model.9.m.0.cv1.bn.num_batches_tracked    -    model.9.m.0.cv1.bn.num_batches_tracked
# model.9.m.0.cv2.conv.weight    -    model.9.m.0.cv2.conv.weight
# model.9.m.0.cv2.bn.weight    -    model.9.m.0.cv2.bn.weight
# model.9.m.0.cv2.bn.bias    -    model.9.m.0.cv2.bn.bias
# model.9.m.0.cv2.bn.running_mean    -    model.9.m.0.cv2.bn.running_mean
# model.9.m.0.cv2.bn.running_var    -    model.9.m.0.cv2.bn.running_var
# model.9.m.0.cv2.bn.num_batches_tracked    -    model.9.m.0.cv2.bn.num_batches_tracked
# model.10.conv.weight    -    model.10.conv.weight
# model.10.bn.weight    -    model.10.bn.weight
# model.10.bn.bias    -    model.10.bn.bias
# model.10.bn.running_mean    -    model.10.bn.running_mean
# model.10.bn.running_var    -    model.10.bn.running_var
# model.10.bn.num_batches_tracked    -    model.10.bn.num_batches_tracked
# model.13.cv1.conv.weight    -    model.13.cv1.conv.weight
# model.13.cv1.bn.weight    -    model.13.cv1.bn.weight
# model.13.cv1.bn.bias    -    model.13.cv1.bn.bias
# model.13.cv1.bn.running_mean    -    model.13.cv1.bn.running_mean
# model.13.cv1.bn.running_var    -    model.13.cv1.bn.running_var
# model.13.cv1.bn.num_batches_tracked    -    model.13.cv1.bn.num_batches_tracked
# model.13.cv2.weight    -    model.13.cv2.weight
# model.13.cv3.weight    -    model.13.cv3.weight
# model.13.cv4.conv.weight    -    model.13.cv4.conv.weight
# model.13.cv4.bn.weight    -    model.13.cv4.bn.weight
# model.13.cv4.bn.bias    -    model.13.cv4.bn.bias
# model.13.cv4.bn.running_mean    -    model.13.cv4.bn.running_mean
# model.13.cv4.bn.running_var    -    model.13.cv4.bn.running_var
# model.13.cv4.bn.num_batches_tracked    -    model.13.cv4.bn.num_batches_tracked
# model.13.bn.weight    -    model.13.bn.weight
# model.13.bn.bias    -    model.13.bn.bias
# model.13.bn.running_mean    -    model.13.bn.running_mean
# model.13.bn.running_var    -    model.13.bn.running_var
# model.13.bn.num_batches_tracked    -    model.13.bn.num_batches_tracked
# model.13.m.0.cv1.conv.weight    -    model.13.m.0.cv1.conv.weight
# model.13.m.0.cv1.bn.weight    -    model.13.m.0.cv1.bn.weight
# model.13.m.0.cv1.bn.bias    -    model.13.m.0.cv1.bn.bias
# model.13.m.0.cv1.bn.running_mean    -    model.13.m.0.cv1.bn.running_mean
# model.13.m.0.cv1.bn.running_var    -    model.13.m.0.cv1.bn.running_var
# model.13.m.0.cv1.bn.num_batches_tracked    -    model.13.m.0.cv1.bn.num_batches_tracked
# model.13.m.0.cv2.conv.weight    -    model.13.m.0.cv2.conv.weight
# model.13.m.0.cv2.bn.weight    -    model.13.m.0.cv2.bn.weight
# model.13.m.0.cv2.bn.bias    -    model.13.m.0.cv2.bn.bias
# model.13.m.0.cv2.bn.running_mean    -    model.13.m.0.cv2.bn.running_mean
# model.13.m.0.cv2.bn.running_var    -    model.13.m.0.cv2.bn.running_var
# model.13.m.0.cv2.bn.num_batches_tracked    -    model.13.m.0.cv2.bn.num_batches_tracked
# model.14.conv.weight    -    model.14.conv.weight
# model.14.bn.weight    -    model.14.bn.weight
# model.14.bn.bias    -    model.14.bn.bias
# model.14.bn.running_mean    -    model.14.bn.running_mean
# model.14.bn.running_var    -    model.14.bn.running_var
# model.14.bn.num_batches_tracked    -    model.14.bn.num_batches_tracked
# model.17.cv1.conv.weight    -    model.17.cv1.conv.weight
# model.17.cv1.bn.weight    -    model.17.cv1.bn.weight
# model.17.cv1.bn.bias    -    model.17.cv1.bn.bias
# model.17.cv1.bn.running_mean    -    model.17.cv1.bn.running_mean
# model.17.cv1.bn.running_var    -    model.17.cv1.bn.running_var
# model.17.cv1.bn.num_batches_tracked    -    model.17.cv1.bn.num_batches_tracked
# model.17.cv2.weight    -    model.17.cv2.weight
# model.17.cv3.weight    -    model.17.cv3.weight
# model.17.cv4.conv.weight    -    model.17.cv4.conv.weight
# model.17.cv4.bn.weight    -    model.17.cv4.bn.weight
# model.17.cv4.bn.bias    -    model.17.cv4.bn.bias
# model.17.cv4.bn.running_mean    -    model.17.cv4.bn.running_mean
# model.17.cv4.bn.running_var    -    model.17.cv4.bn.running_var
# model.17.cv4.bn.num_batches_tracked    -    model.17.cv4.bn.num_batches_tracked
# model.17.bn.weight    -    model.17.bn.weight
# model.17.bn.bias    -    model.17.bn.bias
# model.17.bn.running_mean    -    model.17.bn.running_mean
# model.17.bn.running_var    -    model.17.bn.running_var
# model.17.bn.num_batches_tracked    -    model.17.bn.num_batches_tracked
# model.17.m.0.cv1.conv.weight    -    model.17.m.0.cv1.conv.weight
# model.17.m.0.cv1.bn.weight    -    model.17.m.0.cv1.bn.weight
# model.17.m.0.cv1.bn.bias    -    model.17.m.0.cv1.bn.bias
# model.17.m.0.cv1.bn.running_mean    -    model.17.m.0.cv1.bn.running_mean
# model.17.m.0.cv1.bn.running_var    -    model.17.m.0.cv1.bn.running_var
# model.17.m.0.cv1.bn.num_batches_tracked    -    model.17.m.0.cv1.bn.num_batches_tracked
# model.17.m.0.cv2.conv.weight    -    model.17.m.0.cv2.conv.weight
# model.17.m.0.cv2.bn.weight    -    model.17.m.0.cv2.bn.weight
# model.17.m.0.cv2.bn.bias    -    model.17.m.0.cv2.bn.bias
# model.17.m.0.cv2.bn.running_mean    -    model.17.m.0.cv2.bn.running_mean
# model.17.m.0.cv2.bn.running_var    -    model.17.m.0.cv2.bn.running_var
# model.17.m.0.cv2.bn.num_batches_tracked    -    model.17.m.0.cv2.bn.num_batches_tracked
# model.18.conv.weight    -    model.18.conv.weight
# model.18.bn.weight    -    model.18.bn.weight
# model.18.bn.bias    -    model.18.bn.bias
# model.18.bn.running_mean    -    model.18.bn.running_mean
# model.18.bn.running_var    -    model.18.bn.running_var
# model.18.bn.num_batches_tracked    -    model.18.bn.num_batches_tracked
# model.20.cv1.conv.weight    -    model.20.cv1.conv.weight
# model.20.cv1.bn.weight    -    model.20.cv1.bn.weight
# model.20.cv1.bn.bias    -    model.20.cv1.bn.bias
# model.20.cv1.bn.running_mean    -    model.20.cv1.bn.running_mean
# model.20.cv1.bn.running_var    -    model.20.cv1.bn.running_var
# model.20.cv1.bn.num_batches_tracked    -    model.20.cv1.bn.num_batches_tracked
# model.20.cv2.weight    -    model.20.cv2.weight
# model.20.cv3.weight    -    model.20.cv3.weight
# model.20.cv4.conv.weight    -    model.20.cv4.conv.weight
# model.20.cv4.bn.weight    -    model.20.cv4.bn.weight
# model.20.cv4.bn.bias    -    model.20.cv4.bn.bias
# model.20.cv4.bn.running_mean    -    model.20.cv4.bn.running_mean
# model.20.cv4.bn.running_var    -    model.20.cv4.bn.running_var
# model.20.cv4.bn.num_batches_tracked    -    model.20.cv4.bn.num_batches_tracked
# model.20.bn.weight    -    model.20.bn.weight
# model.20.bn.bias    -    model.20.bn.bias
# model.20.bn.running_mean    -    model.20.bn.running_mean
# model.20.bn.running_var    -    model.20.bn.running_var
# model.20.bn.num_batches_tracked    -    model.20.bn.num_batches_tracked
# model.20.m.0.cv1.conv.weight    -    model.20.m.0.cv1.conv.weight
# model.20.m.0.cv1.bn.weight    -    model.20.m.0.cv1.bn.weight
# model.20.m.0.cv1.bn.bias    -    model.20.m.0.cv1.bn.bias
# model.20.m.0.cv1.bn.running_mean    -    model.20.m.0.cv1.bn.running_mean
# model.20.m.0.cv1.bn.running_var    -    model.20.m.0.cv1.bn.running_var
# model.20.m.0.cv1.bn.num_batches_tracked    -    model.20.m.0.cv1.bn.num_batches_tracked
# model.20.m.0.cv2.conv.weight    -    model.20.m.0.cv2.conv.weight
# model.20.m.0.cv2.bn.weight    -    model.20.m.0.cv2.bn.weight
# model.20.m.0.cv2.bn.bias    -    model.20.m.0.cv2.bn.bias
# model.20.m.0.cv2.bn.running_mean    -    model.20.m.0.cv2.bn.running_mean
# model.20.m.0.cv2.bn.running_var    -    model.20.m.0.cv2.bn.running_var
# model.20.m.0.cv2.bn.num_batches_tracked    -    model.20.m.0.cv2.bn.num_batches_tracked
# model.21.conv.weight    -    model.21.conv.weight
# model.21.bn.weight    -    model.21.bn.weight
# model.21.bn.bias    -    model.21.bn.bias
# model.21.bn.running_mean    -    model.21.bn.running_mean
# model.21.bn.running_var    -    model.21.bn.running_var
# model.21.bn.num_batches_tracked    -    model.21.bn.num_batches_tracked
# model.23.cv1.conv.weight    -    model.23.cv1.conv.weight
# model.23.cv1.bn.weight    -    model.23.cv1.bn.weight
# model.23.cv1.bn.bias    -    model.23.cv1.bn.bias
# model.23.cv1.bn.running_mean    -    model.23.cv1.bn.running_mean
# model.23.cv1.bn.running_var    -    model.23.cv1.bn.running_var
# model.23.cv1.bn.num_batches_tracked    -    model.23.cv1.bn.num_batches_tracked
# model.23.cv2.weight    -    model.23.cv2.weight
# model.23.cv3.weight    -    model.23.cv3.weight
# model.23.cv4.conv.weight    -    model.23.cv4.conv.weight
# model.23.cv4.bn.weight    -    model.23.cv4.bn.weight
# model.23.cv4.bn.bias    -    model.23.cv4.bn.bias
# model.23.cv4.bn.running_mean    -    model.23.cv4.bn.running_mean
# model.23.cv4.bn.running_var    -    model.23.cv4.bn.running_var
# model.23.cv4.bn.num_batches_tracked    -    model.23.cv4.bn.num_batches_tracked
# model.23.bn.weight    -    model.23.bn.weight
# model.23.bn.bias    -    model.23.bn.bias
# model.23.bn.running_mean    -    model.23.bn.running_mean
# model.23.bn.running_var    -    model.23.bn.running_var
# model.23.bn.num_batches_tracked    -    model.23.bn.num_batches_tracked
# model.23.m.0.cv1.conv.weight    -    model.23.m.0.cv1.conv.weight
# model.23.m.0.cv1.bn.weight    -    model.23.m.0.cv1.bn.weight
# model.23.m.0.cv1.bn.bias    -    model.23.m.0.cv1.bn.bias
# model.23.m.0.cv1.bn.running_mean    -    model.23.m.0.cv1.bn.running_mean
# model.23.m.0.cv1.bn.running_var    -    model.23.m.0.cv1.bn.running_var
# model.23.m.0.cv1.bn.num_batches_tracked    -    model.23.m.0.cv1.bn.num_batches_tracked
# model.23.m.0.cv2.conv.weight    -    model.23.m.0.cv2.conv.weight
# model.23.m.0.cv2.bn.weight    -    model.23.m.0.cv2.bn.weight
# model.23.m.0.cv2.bn.bias    -    model.23.m.0.cv2.bn.bias
# model.23.m.0.cv2.bn.running_mean    -    model.23.m.0.cv2.bn.running_mean
# model.23.m.0.cv2.bn.running_var    -    model.23.m.0.cv2.bn.running_var
# model.23.m.0.cv2.bn.num_batches_tracked    -    model.23.m.0.cv2.bn.num_batches_tracked
# model.24.anchors    -    model.24.anchors
# model.24.m.0.weight    -    model.24.m.0.weight
# model.24.m.0.bias    -    model.24.m.0.bias
# model.24.m.1.weight    -    model.24.m.1.weight
# model.24.m.1.bias    -    model.24.m.1.bias
# model.24.m.2.weight    -    model.24.m.2.weight
# model.24.m.2.bias    -    model.24.m.2.bias

# %%
ymd = custom_yolo_model.state_dict()
new_ymd = dict()

for k,v in ymd.items():
    new_ymd[k[6:]] = v

# %%
new_ymk = list(new_ymd.keys())
fek = list(feature_extractor.state_dict().keys())

counter=0

for i in range(len(new_ymk)):
    # print("model.",new_ymk[i]," - ",fek[i])
    if("model."+new_ymk[i]==fek[i]):
        counter+=1

counter
# Out:
# 369

# %%
feature_extractor.load_another(new_ymd)

# %%
class GeneratorLoss(nn.Module):
  def __init__(self):
    super(GeneratorLoss, self).__init__()
    # vgg = vgg16(pretrained=True)
    # loss_network = nn.Sequential(*list(vgg.features)[:31]).eval()
    loss_network = feature_extractor
    for param in loss_network.parameters():
      param.requires_grad = False
    self.loss_network = loss_network
    self.mse_loss = nn.MSELoss()
    self.tv_loss = TVLoss()
  def forward(self, out_labels, out_images, target_images):
    adversial_loss = torch.mean(1 - out_labels)
    perception_loss = self.mse_loss(out_images, target_images)
    image_loss = self.mse_loss(out_images, target_images)
    tv_loss = self.tv_loss(out_images)
    return image_loss + 0.001 * adversial_loss + 0.006 * perception_loss + 2e-8 * tv_loss

# %%
device  = torch.device("cpu")
#device  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Standard device selectoin
device
# Out:
# device(type='cpu')

# %%
netG = Generator(UPSCALE_FACTOR)
netD = Discriminator()

# %%
generator_criterion = GeneratorLoss()

# %%
generator_criterion = generator_criterion.to(device)
netG = netG.to(device)
netD = netD.to(device)

# %%
optimizerG = optim.Adam(netG.parameters(), lr=0.0002)
optimizerD = optim.Adam(netD.parameters(), lr=0.0002)

# %%
results = {
    "d_loss":[],
    "g_loss":[],
    "d_score": [],
    "g_score": []
}

# %%
## Now for training code
from tqdm import tqdm
import os

# %%
N_EPOCHS = 1 # 150 is good enough for our model. gives decent enough results

# %%
for epoch in range(1, N_EPOCHS + 1):
  train_bar = tqdm(trainloader)
  running_results = {'batch_sizes':0, 'd_loss':0,
                     "g_loss":0, "d_score":0, "g_score":0}

  netG.train()
  netD.train()
  for data, target in train_bar:
    g_update_first = True
    batch_size = data.size(0)
    running_results['batch_sizes'] += batch_size

    real_img = Variable(target)
    real_img = real_img.to(device)
    z = Variable(data)
    z = z.to(device)

    ## Update Discriminator ##
    fake_img = netG(z)
    netD.zero_grad()
    real_out = netD(real_img).mean()
    fake_out = netD(fake_img).mean()
    d_loss = 1 - real_out + fake_out
    d_loss.backward(retain_graph = True)
    optimizerD.step()

    ## Now update Generator
    fake_img = netG(z)
    fake_out = netD(fake_img).mean()
    netG.zero_grad()
    g_loss = generator_criterion(fake_out, fake_img, real_img)
    g_loss.backward()

    fake_img = netG(z)
    fake_out = netD(fake_img).mean()

    optimizerG.step()

    running_results['g_loss'] += g_loss.item() * batch_size
    running_results['d_loss'] += d_loss.item() * batch_size
    running_results['d_score'] += real_out.item() * batch_size
    running_results['g_score'] += real_out.item() * batch_size

    ## Updating the progress bar
    train_bar.set_description(desc="[%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f" % (
        epoch, N_EPOCHS, running_results['d_loss'] / running_results['batch_sizes'],
        running_results['g_loss'] / running_results['batch_sizes'],
        running_results['d_score'] / running_results['batch_sizes'],
        running_results['g_score'] / running_results['batch_sizes']
    ))
  netG.eval()
# Out:
# [1/1] Loss_D: 0.7469 Loss_G: 0.1184 D(x): 0.6382 D(G(z)): 0.6382:  61%|██████▏   | 19/31 [31:37<19:58, 99.87s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 19
#      16 z = z.to(device)
#      18 ## Update Discriminator ##
# ---> 19 fake_img = netG(z)
#      20 netD.zero_grad()
#      21 real_out = netD(real_img).mean()
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[17], line 29, in Generator.forward(self, x)
#      27 block4 = self.block4(block3)
#      28 block5 = self.block5(block4)
# ---> 29 block6 = self.block6(block5)
#      30 block7 = self.block7(block6)
#      31 block8 = self.block8(block1 + block7)
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[15], line 14, in ResidualBlock.forward(self, x)
#      12 residual = self.conv1(x)
#      13 residual = self.bn1(residual)
# ---> 14 residual = self.prelu(residual)
#      15 residual = self.conv2(residual)
#      16 residual = self.bn2(residual)
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\computers\Python\Environments\Pytorch cuda env\.venv\lib\site-packages\torch\nn\modules\activation.py:1364, in PReLU.forward(self, input)
#    1363 def forward(self, input: Tensor) -> Tensor:
# -> 1364     return F.prelu(input, self.weight)
#
# KeyboardInterrupt:

# %%
# Path to the directory you want to list
main_path = './srgan_results'

# List all files and folders in the directory
files = os.listdir(main_path)

# Print the list of files
for file in files:
    print(file)
# Out:
# discriminator_10epoch_crop160.pt
# discriminator_10epoch_crop160_noAct.pt
# discriminator_20epoch_crop160_noAct.pt
# discriminator_30epoch_crop160_noAct.pt
# discriminator_40epoch_crop160_noAct.pt
# discriminator_content2_10epoch_crop160_noAct.pt
# discriminator_content2_20epoch_crop160_noAct.pt
# discriminator_content2_30epoch_crop160_noAct.pt
# discriminator_content2_40epoch_crop160_noAct.pt
# discriminator_content_10epoch_crop160_noAct.pt
# discriminator_content_20epoch_crop160_noAct.pt
# discriminator_content_30epoch_crop160_noAct.pt
# discriminator_content_40epoch_crop160_noAct.pt
# generator_10epoch_crop160.pt
# generator_10epoch_crop160_noAct.pt
# generator_20epoch_crop160_noAct.pt
# generator_30epoch_crop160_noAct.pt
# generator_40epoch_crop160_noAct.pt
# generator_content2_10epoch_crop160_noAct.pt
# generator_content2_20epoch_crop160_noAct.pt
# generator_content2_30epoch_crop160_noAct.pt
# generator_content2_40epoch_crop160_noAct.pt
# generator_content_10epoch_crop160_noAct.pt
# generator_content_20epoch_crop160_noAct.pt
# generator_content_30epoch_crop160_noAct.pt
# generator_content_40epoch_crop160_noAct.pt

# %%
torch.save(netG.state_dict(),main_path+"/generator_40epoch_crop160_noAct.pt")
torch.save(netD.state_dict(),main_path+"/discriminator_40epoch_crop160_noAct.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 torch.save(netG.state_dict(),main_path+"/generator_40epoch_crop160_noAct.pt")
#       2 torch.save(netD.state_dict(),main_path+"/discriminator_40epoch_crop160_noAct.pt")
#
# NameError: name 'netG' is not defined

# %% [markdown]
# After training

# %%
srm = Generator(UPSCALE_FACTOR)
srm = srm
srm.load_state_dict(torch.load(main_path+"/generator_content_40epoch_crop160_noAct.pt",map_location=device))
srm.eval()
# Out:
# Generator(
#   (block1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (1): PReLU(num_parameters=1)
#   )
#   (block2): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block3): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block4): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block5): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block6): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block7): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block8): Sequential(
#     (0): Conv2d(64, 3, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#   )
# )

# %%
valid_set = createDataset(dataset_path,"valid")
validloader = DataLoader(valid_set,batch_size=16,shuffle=True)

# %%
# %matplotlib inline
lrimages,hrimages = next(iter(validloader))
srimages = srm(lrimages).detach()
srimages = (srimages - torch.min(srimages)) / (torch.max(srimages) - torch.min(srimages))
print(lrimages.size(),hrimages.size(),srimages.size())

fig,axes = plt.subplots(4,3,figsize=(28,21))

for i in range(4):  # Assuming we want to plot the first 4 images
    # Low-resolution image
    axes[i, 0].imshow(lrimages[i].squeeze().permute(1, 2, 0).numpy())
    axes[i, 0].axis("off")
    if i == 0:
        axes[i, 0].set_title("LR")

    # High-resolution image
    axes[i, 1].imshow(hrimages[i].squeeze().permute(1, 2, 0).numpy())
    axes[i, 1].axis("off")
    if i == 0:
        axes[i, 1].set_title("HR")

    # Model interpretation image
    axes[i, 2].imshow(srimages[i].permute(1, 2, 0).cpu().numpy())
    axes[i, 2].axis("off")
    if i == 0:
        axes[i, 2].set_title("SR")

plt.tight_layout()
plt.show()
# Out:
# torch.Size([16, 3, 160, 160]) torch.Size([16, 3, 160, 160]) torch.Size([16, 3, 160, 160])

# %%
(srimages).max(),(srimages).min(),(srimages).mean()
# Out:
# (tensor(1.), tensor(0.), tensor(0.37240))

# %%
(hrimages).max(),(hrimages).min(),(hrimages).mean()
# Out:
# (tensor(1.), tensor(0.), tensor(0.41204))
